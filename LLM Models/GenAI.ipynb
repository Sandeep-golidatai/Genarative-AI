# %%
# !pip install google-generativeai

# %%
import os
import google.generativeai as genai
api_key='AIzaSyAfApyeIY7GYJ4lR6fwg9G60n7wW9Izaro'
genai.configure(api_key=api_key)

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model=genai.GenerativeModel("gemini-pro")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
respone=model.generate_content("List of 5 top crickters in india")
respone
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': '1. Virat Kohli\n2. Rohit Sharma\n3. KL Rahul\n4. Jasprit Bumrah\n5. Ravindra Jadeja'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}]}),
# )

# %%
respone.text
# Out:
# '1. Virat Kohli\n2. Rohit Sharma\n3. KL Rahul\n4. Jasprit Bumrah\n5. Ravindra Jadeja'

# %%
dir(model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_async_client',
#  '_client',
#  '_generation_config',
#  '_get_tools_lib',
#  '_model_name',
#  '_prepare_request',
#  '_safety_settings',
#  '_system_instruction',
#  '_tool_config',
#  '_tools',
#  'count_tokens',
#  'count_tokens_async',
#  'generate_content',
#  'generate_content_async',
#  'model_name',
#  'start_chat']

# %%
dir(respone)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_chunks',
#  '_done',
#  '_error',
#  '_iterator',
#  '_result',
#  'candidates',
#  'from_iterator',
#  'from_response',
#  'parts',
#  'prompt_feedback',
#  'resolve',
#  'text']

# %%
import os
import google.generativeai as genai
api_key='AIzaSyAfApyeIY7GYJ4lR6fwg9G60n7wW9Izaro'
genai.configure(api_key=api_key)

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model=genai.GenerativeModel('gemini-pro')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
respons=model.generate_content('what is transfer learing')
print(respons.text)
# Out:
# **Transfer Learning**
#
# Transfer learning is a machine learning technique where a model trained on one task is reused as the starting point for a model on a second task. This allows the second model to leverage the knowledge gained from the first task, improving its performance and reducing training time.
#
# **How Transfer Learning Works:**
#
# 1. **Train a Source Model:** A model is trained on a large dataset for a specific task, such as image classification.
# 2. **Extract Features:** The trained model's intermediate layers learn feature representations that are useful for related tasks.
# 3. **Freeze Source Model Layers:** The lower layers of the source model, which learned general features, are frozen (not updated).
# 4. **Add New Layers:** New layers are added to the top of the source model to adapt it to the new task.
# 5. **Fine-tune Model:** The entire model, including the new layers, is fine-tuned on a new dataset for the target task.
#
# ...

# %%
respone=model.generate_content("List of 5 top crickters in india")
respone
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': '1. Virat Kohli\n2. Rohit Sharma\n3. KL Rahul\n4. Ravindra Jadeja\n5. Jasprit Bumrah'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}]}),
# )

# %%
from PIL import Image
# from IPython.display import Image

# %%
image=Image.pen('/royal-enfield-2a.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1911x1037>
