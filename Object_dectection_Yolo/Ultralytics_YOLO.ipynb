# %%
# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 15.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import ultralytics

dir(ultralytics)
# Out:
# ['ASSETS',
#  'Explorer',
#  'FastSAM',
#  'NAS',
#  'RTDETR',
#  'SAM',
#  'SETTINGS',
#  'YOLO',
#  'YOLOWorld',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'cfg',
#  'checks',
#  'data',
#  'download',
#  'engine',
#  'hub',
#  'models',
#  'nn',
#  'os',
#  'settings',
#  'utils']

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 94.1MB/s]
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
# ...

# %%
dir(model)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_backward_pre_hooks',
#  '_buffers',
#  '_call_impl',
#  '_check_is_pytorch_model',
#  '_compiled_call_impl',
#  '_forward_hooks',
#  '_forward_hooks_always_called',
#  '_forward_hooks_with_kwargs',
#  '_forward_pre_hooks',
#  '_forward_pre_hooks_with_kwargs',
#  '_get_backward_hooks',
#  '_get_backward_pre_hooks',
#  '_get_hub_session',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load',
#  '_load_from_state_dict',
# ...

# %%
model.info()
# Out:
# YOLOv8n summary: 225 layers, 3157200 parameters, 0 gradients, 8.9 GFLOPs
# (225, 3157200, 0, 8.8575488)

# %%
model.model_name
# Out:
# 'yolov8n.pt'

# %%
# re/sults = model(["/content/dog.jpg", "/content/zidane.jpg"])
results = model(["/content/person.jpg", "/content/zidane.jpg"])

for result in results:
  boxes=result.boxes
  mask=result.masks
  keypoints = result.keypoints
  probs = result.probs
  obb = result.obb
  result.show()
# Out:
# 0: 640x640 1 person, 1 dog, 1 horse, 322.9ms
# 1: 640x640 2 persons, 1 tie, 322.9ms
# Speed: 29.6ms preprocess, 322.9ms inference, 15.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
dir(results)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Perform inference on images
results = model(["/content/person.jpg", "/content/zidane.jpg"])

# Iterate through the results
for i, result in enumerate(results):
    # Extract bounding boxes, classes, names, and confidences
    boxes = result.boxes.xyxy.tolist()
    classes = result.boxes.cls.tolist()
    names = result.names
    confidences = result.boxes.conf.tolist()

    # Load the original image
    img = cv2.imread(f"/content/person.jpg" if i == 0 else f"/content/zidane.jpg")

    # Iterate through the results and draw bounding boxes on the image
    for box, cls, conf in zip(boxes, classes, confidences):
        x1, y1, x2, y2 = map(int, box)
        confidence = conf
        detected_class = cls
        name = names[int(cls)]

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        # Put text label
        cv2.putText(img, f"{name}: {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the image with bounding boxes
    cv2_imshow(img)
# Out:
# 0: 640x640 1 person, 1 dog, 1 horse, 765.2ms
# 1: 640x640 2 persons, 1 tie, 765.2ms
# Speed: 17.6ms preprocess, 765.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x424>
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Perform inference on images
results = model(["/content/dog.jpg", "/content/zidane.jpg"])

# Iterate through the results
for i, result in enumerate(results):
    # Extract bounding boxes, classes, names, and confidences
    boxes = result.boxes.xyxy.tolist()
    classes = result.boxes.cls.tolist()
    names = result.names
    confidences = result.boxes.conf.tolist()

    # Load the original image
    img = cv2.imread(f"/content/dog.jpg" if i == 0 else f"/content/zidane.jpg")

    # Iterate through the results and draw bounding boxes on the image
    for box, cls, conf in zip(boxes, classes, confidences):
        x1, y1, x2, y2 = map(int, box)
        confidence = conf
        detected_class = cls
        name = names[int(cls)]

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        # Put text label
        cv2.putText(img, f"{name}: {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the image with bounding boxes
    cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Perform inference on an image
results = model('https://ultralytics.com/images/bus.jpg')

# Extract bounding boxes, classes, names, and confidences
boxes = results[0].boxes.xyxy.tolist()
classes = results[0].boxes.cls.tolist()
names = results[0].names
confidences = results[0].boxes.conf.tolist()

# Load the original image
img = cv2.imread('bus.jpg')

# Iterate through the results and draw bounding boxes on the image
for box, cls, conf in zip(boxes, classes, confidences):
    x1, y1, x2, y2 = map(int, box)
    confidence = conf
    detected_class = cls
    name = names[int(cls)]

    # Draw bounding box
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    # Put text label
    cv2.putText(img, f"{name}: {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the image with bounding boxes
cv2_imshow(img)
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 14.0MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 316.4ms
# Speed: 6.3ms preprocess, 316.4ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=810x1080>

# %%
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Perform inference on images
results = model(["/content/giraffe.jpg", "/content/kite.jpg"])

# Iterate through the results
for i, result in enumerate(results):
    # Extract bounding boxes, classes, names, and confidences
    boxes = result.boxes.xyxy.tolist()
    classes = result.boxes.cls.tolist()
    names = result.names
    confidences = result.boxes.conf.tolist()

    # Load the original image
    img = cv2.imread(f"/content/giraffe.jpg" if i == 0 else f"/content/kite.jpg")

    # Iterate through the results and draw bounding boxes on the image
    for box, cls, conf in zip(boxes, classes, confidences):
        x1, y1, x2, y2 = map(int, box)
        confidence = conf
        detected_class = cls
        name = names[int(cls)]

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        # Put text label
        cv2.putText(img, f"{name}: {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the image with bounding boxes
    cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
dir(results)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
for i, result in enumerate(results):
    # Extract bounding boxes, classes, names, and confidences
    boxes = result.boxes.xyxy.tolist()
    classes = result.boxes.cls.tolist()
    names = result.names
    confidences = result.boxes.conf.tolist()
    # print(confidences)
    # print(len(confidences))
    for box, cls, conf in zip(boxes, classes, confidences):
        x1, y1, x2, y2 = map(int, box)
        confidence = conf
        detected_class = cls
        name = names[int(cls)]
        print(name)
        # print(x1, y1, x2, y2)
        # print( x2)
        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        # Put text label
        cv2.putText(img, f"{name}: {confidence:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
# Out:
# zebra
# giraffe
# kite
# person
# person
# kite
# person
# kite
# kite
# person
# person
# person
# person
# person
# kite
